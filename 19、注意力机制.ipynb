# %% [markdown]
# 注意力机制，也是在处理大量文本、图像、视频等信息时，的一种自然而然亟待的需求，当在处理简单的句子，小图像，可能就用不到它... 我们需要处理很多聚焦，总结类的任务时，并不需要处理全部的输入信息，这就要求模型能够实现有针对性的聚焦，同时，还需要其具备记忆的能力，可读可写等。
#
# 记忆网络的进阶版，能够实现循环抽取强关联的信息，具体如下图所示（需要说明的是计算match score的方法有很多，一般还是用余弦相似度）：
#
# ![Memory%20Network.png](attachment:Memory%20Network.png)
#
# Multiple-hop其实就是对问题聚焦对象的逼近，比如我们提问，要在一个物体的上方找有没有什么？那至少需要2次，一次找到这个物体，然后在物体上方有没有什么？这跟人的判断逻辑也是一样的！
#
# ![multiple-hop.png](attachment:multiple-hop.png)
# ![R-Net.png](attachment:R-Net.png)
# ![Bi-directional%20Attention%20Flow.png](attachment:Bi-directional%20Attention%20Flow.png)
# ![Fully-Aware%20Fusion%20Network.png](attachment:Fully-Aware%20Fusion%20Network.png)
#
# 可以写入的例子，Neural Turing Machine（太复杂，不好train，不实用）
#
# ![NTM1.png](attachment:NTM1.png)
# ![NTM2.png](attachment:NTM2.png)
# ![NTM3.png](attachment:NTM3.png)
