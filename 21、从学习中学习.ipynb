# %% [markdown]
# 我们知道在机器学习中对于参数的微调方法有网格搜索，和随机搜索。除此，我们还可以通过建模来实现，比如使用强化学习，要选择参数的集合，就是action的集合，比如学习学习率，学习激活函数等，这种方式就几乎变成了自动学习了，但是还是存在不确定性...
#
# ![Learnable.png](attachment:Learnable.png)
# ![auto_learning%20activation%20function.png](attachment:auto_learning%20activation%20function.png)
#
# 但是这个任务，对于普通人来说是几乎无法完成的，因为需要的硬件资源真的是很昂贵！！
